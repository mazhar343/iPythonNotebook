# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:/Users/acesi/OneDrive/Desktop/Excel_files/Sample - Superstore.xlsx")
# Out:
# c:\Users\acesi\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df.shape
# Out:
# (9994, 21)

# %%
fig ,ax = plt.subplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\acesi\OneDrive\Desktop\Aces\my_practice\interpretered\pie.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/acesi/OneDrive/Desktop/Aces/my_practice/interpretered/pie.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> fig ,ax = plt.subplot()
#
# TypeError: cannot unpack non-iterable AxesSubplot object

# %%
# my_circle = plt.Circle((0, 0), 0.7, color='white')
y=df['Sales']
x=df['Category']
# plt.pie(y, labels=x, autopct='%1.1f%%',)

# p = plt.gcf()
# p.gca().add_artist(my_circle)

# %%
data = df.groupby('Category').agg({'Sales':sum})

# %%
l = list(data['Sales'])

# %%
l
# Out:
# [2000.3375, 177.672, 907.152]

# %%
label = list(data.index)

# %%
my_circle = plt.Circle((0, 0), 0.2, color='black')

# %%
plt.pie(x=l, labels=label, autopct='%1.1f%%',startangle = 90)

plt.show()

# %%
plt.pie(x=l, labels=label, autopct='%1.1f%%',startangle = 90)

plt.show()
p = plt.gcf()
p.gca().add_artist(my_circle)

# %%
x.unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
len(y)
# Out:
# 9994

# %%
data = df.groupby('Category').agg({'Sales':sum})

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11  Second Class    CG-12520
#
#   Customer Name   Segment Country/Region       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %%
data
# Out:
#                        Sales
# Category
# Furniture        741999.7953
# Office Supplies  719047.0320
# Technology       836154.0330

# %%
x = list(data.index)

# %%
x
# Out:
# ['Furniture', 'Office Supplies', 'Technology']

# %%
y
