# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:/Users/acesi/OneDrive/Desktop/Excel_files/Sample - Superstore2.xlsx")

# %% [markdown]
# ## Table Calculation

# %%
df.shape
# Out:
# (9994, 21)

# %%
df['Order Date']= pd.to_datetime(df['Order Date'])

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State                     object
# Postal Code              float64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
sales_by_year = df.groupby([df['Category'],'Sub-Category']).aggregate({'Sales':sum})

# %%
sales_by_year
# Out:
#                                     Sales
# Category        Sub-Category
# Furniture       Bookcases     114879.9963
#                 Chairs        328449.1030
#                 Furnishings    91705.1640
#                 Tables        206965.5320
# Office Supplies Appliances    107532.1610
#                 Art            27118.7920
#                 Binders       203412.7330
#                 Envelopes      16476.4020
#                 Fasteners       3024.2800
#                 Labels         12486.3120
#                 Paper          78479.2060
#                 Storage       223843.6080
#                 Supplies       46673.5380
# Technology      Accessories   167380.3180
#                 Copiers       149528.0300
#                 Machines      189238.6310
#                 Phones        330007.0540

# %%
sales = sales_by_year.unstack(level=-2)

# %%
# sales.size()

# %%
import matplotlib.pyplot as plt

# %%
df.groupby(['Category','Sub-Category']).aggregate({'Sales':sum}).unstack(-2).plot(kind = 'bar',stacked= True,figsize = (15,7) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\acesi\OneDrive\Desktop\Aces\my_practice\interpretered\Untitled1.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/acesi/OneDrive/Desktop/Aces/my_practice/interpretered/Untitled1.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> df.groupby(['Category','Sub-Category']).aggregate({'Sales':sum}).unstack(-2).plot(kind = 'bar',stacked= True,figsize = (15,7) )
#
# NameError: name 'df' is not defined

# %%
# plt.stackplot(df['Sub-Category'],df['Sales'])

# %%
dfd = df.groupby(['Region','Sub-Category']).aggregate({'Sales':sum}).unstack(-2)

# %%
dfd.index
# Out:
# Index(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases', 'Chairs',
#        'Copiers', 'Envelopes', 'Fasteners', 'Furnishings', 'Labels',
#        'Machines', 'Paper', 'Phones', 'Storage', 'Supplies', 'Tables'],
#       dtype='object', name='Sub-Category')

# %%
import matplotlib.pyplot as plt
fig, plot1 = plt.subplots(figsize =(7, 5))

# %%
fig= dfd.plot( kind='bar' ,subplots=True)

# %%
fig
# plt.show()
# Out:
# array([<AxesSubplot:title={'center':'(Sales, Central)'}, xlabel='Sub-Category'>,
#        <AxesSubplot:title={'center':'(Sales, East)'}, xlabel='Sub-Category'>,
#        <AxesSubplot:title={'center':'(Sales, South)'}, xlabel='Sub-Category'>,
#        <AxesSubplot:title={'center':'(Sales, West)'}, xlabel='Sub-Category'>],
#       dtype=object)

# %%
# bar1 = FigureCanvasTkAgg(fig, )
# bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\acesi\OneDrive\Desktop\Aces\my_practice\interpretered\Untitled1.ipynb Cell 20 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/acesi/OneDrive/Desktop/Aces/my_practice/interpretered/Untitled1.ipynb#Y265sZmlsZQ%3D%3D?line=0'>1</a> bar1 = FigureCanvasTkAgg(figure1, root)
#       <a href='vscode-notebook-cell:/c%3A/Users/acesi/OneDrive/Desktop/Aces/my_practice/interpretered/Untitled1.ipynb#Y265sZmlsZQ%3D%3D?line=1'>2</a> bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
#
# NameError: name 'figure1' is not defined

# %%
dfs = df.groupby(['Region','Sub-Category']).aggregate({'Sales':sum}).unstack(-1)
list(dfs.index)
# Out:
# ['Central', 'East', 'South', 'West']

# %%
ax
# Out:
# <AxesSubplot:title={'center':'Bar Chart of Colors'}, xlabel='Sub-Category', ylabel='Sales'>

# %%
sales_by_year
# Out:
#                                     Sales
# Category        Sub-Category
# Furniture       Bookcases     114879.9963
#                 Chairs        328449.1030
#                 Furnishings    91705.1640
#                 Tables        206965.5320
# Office Supplies Appliances    107532.1610
#                 Art            27118.7920
#                 Binders       203412.7330
#                 Envelopes      16476.4020
#                 Fasteners       3024.2800
#                 Labels         12486.3120
#                 Paper          78479.2060
#                 Storage       223843.6080
#                 Supplies       46673.5380
# Technology      Accessories   167380.3180
#                 Copiers       149528.0300
#                 Machines      189238.6310
#                 Phones        330007.0540

# %%
listx = dict(sales_by_year['Sales'])

# %%
x = list(listx.keys())

# %%
for i,j in enumerate(x):
    print(i,'and ', j,'\n')
# Out:
# 0 and  ('Furniture', 'Bookcases')
#
# 1 and  ('Furniture', 'Chairs')
#
# 2 and  ('Furniture', 'Furnishings')
#
# 3 and  ('Furniture', 'Tables')
#
# 4 and  ('Office Supplies', 'Appliances')
#
# 5 and  ('Office Supplies', 'Art')
#
# 6 and  ('Office Supplies', 'Binders')
#
# 7 and  ('Office Supplies', 'Envelopes')
#
# 8 and  ('Office Supplies', 'Fasteners')
#
# 9 and  ('Office Supplies', 'Labels')
#
# 10 and  ('Office Supplies', 'Paper')
#
# 11 and  ('Office Supplies', 'Storage')
#
# 12 and  ('Office Supplies', 'Supplies')
#
# 13 and  ('Technology', 'Accessories')
#
# 14 and  ('Technology', 'Copiers')
#
# 15 and  ('Technology', 'Machines')
#
# 16 and  ('Technology', 'Phones')

# %%
region= df.groupby([df['Region'],'Sub-Category']).aggregate({'Sales':sum})

# %%
region.unstack(level=-2)
# Out:
#                    Sales
# Region           Central        East      South         West
# Sub-Category
# Accessories   33956.0760   45033.372  27276.754   61114.1160
# Appliances    23582.0330   34188.466  19525.326   30236.3360
# Art            5765.3400    7485.764   4655.622    9212.0660
# Binders       56923.2820   53497.997  37030.341   55961.1130
# Bookcases     24157.1768   43819.334  10899.362   36004.1235
# Chairs        85230.6460   96260.683  45176.446  101781.3280
# Copiers       37259.5700   53219.462   9299.756   49749.2420
# Envelopes      4636.8720    4375.874   3345.556    4118.1000
# Fasteners       778.0300     819.718    503.316     923.2160
# Furnishings   15254.3700   29071.380  17306.684   30072.7300
# Labels         2451.4720    2602.934   2353.180    5078.7260
# Machines      26797.3840   66106.165  53890.960   42444.1220
# Paper         17491.9020   20172.602  14150.984   26663.7180
# Phones        72403.2820  100614.982  58304.438   98684.3520
# Storage       45930.1120   71612.584  35768.060   70532.8520
# Supplies       9467.3720   10760.116   8318.928   18127.1220
# Tables        39154.9710   39139.807  43916.192   84754.5620

# %%
region
# Out:
#                            Sales
# Region  Sub-Category
# Central Accessories   33956.0760
#         Appliances    23582.0330
#         Art            5765.3400
#         Binders       56923.2820
#         Bookcases     24157.1768
# ...                          ...
# West    Paper         26663.7180
#         Phones        98684.3520
#         Storage       70532.8520
#         Supplies      18127.1220
#         Tables        84754.5620
#
# [68 rows x 1 columns]

# %%
type(region)
# Out:
# pandas.core.frame.DataFrame

# %%
region.head(50)
# Out:
#                             Sales
# Region  Sub-Category
# Central Accessories    33956.0760
#         Appliances     23582.0330
#         Art             5765.3400
#         Binders        56923.2820
#         Bookcases      24157.1768
#         Chairs         85230.6460
#         Copiers        37259.5700
#         Envelopes       4636.8720
#         Fasteners        778.0300
#         Furnishings    15254.3700
#         Labels          2451.4720
#         Machines       26797.3840
#         Paper          17491.9020
#         Phones         72403.2820
#         Storage        45930.1120
#         Supplies        9467.3720
#         Tables         39154.9710
# East    Accessories    45033.3720
#         Appliances     34188.4660
#         Art             7485.7640
#         Binders        53497.9970
#         Bookcases      43819.3340
#         Chairs         96260.6830
#         Copiers        53219.4620
#         Envelopes       4375.8740
#         Fasteners        819.7180
#         Furnishings    29071.3800
#         Labels          2602.9340
#         Machines       66106.1650
#         Paper          20172.6020
#         Phones        100614.9820
#         Storage        71612.5840
#         Supplies       10760.1160
#         Tables         39139.8070
# South   Accessories    27276.7540
#         Appliances     19525.3260
#         Art             4655.6220
#         Binders        37030.3410
#         Bookcases      10899.3620
#         Chairs         45176.4460
#         Copiers         9299.7560
#         Envelopes       3345.5560
#         Fasteners        503.3160
#         Furnishings    17306.6840
#         Labels          2353.1800
#         Machines       53890.9600
#         Paper          14150.9840
#         Phones         58304.4380
#         Storage        35768.0600
#         Supplies        8318.9280

# %%
print(region.values())
# Out:
# dict_values([Region   Sub-Category
# Central  Accessories     33956.0760
#          Appliances      23582.0330
#          Art              5765.3400
#          Binders         56923.2820
#          Bookcases       24157.1768
#                             ...
# West     Paper           26663.7180
#          Phones          98684.3520
#          Storage         70532.8520
#          Supplies        18127.1220
#          Tables          84754.5620
# Name: Sales, Length: 68, dtype: float64])

# %%
sales_by_year = dict(sales_by_year)

# %%
listkeys = dict(sales_by_year['Sales'])

# %%
x = list(listkeys.keys())

# %%
x
# Out:
# [(2018, 'Appliances'),
#  (2018, 'Art'),
#  (2018, 'Binders'),
#  (2018, 'Furnishings'),
#  (2018, 'Phones'),
#  (2018, 'Storage'),
#  (2018, 'Tables'),
#  (2019, 'Accessories'),
#  (2019, 'Appliances'),
#  (2019, 'Art'),
#  (2019, 'Binders'),
#  (2019, 'Bookcases'),
#  (2019, 'Chairs'),
#  (2019, 'Envelopes'),
#  (2019, 'Furnishings'),
#  (2019, 'Labels'),
#  (2019, 'Paper'),
#  (2019, 'Phones'),
#  (2019, 'Storage'),
#  (2019, 'Tables'),
#  (2020, 'Accessories'),
#  (2020, 'Appliances'),
#  (2020, 'Art'),
#  (2020, 'Binders'),
#  (2020, 'Bookcases'),
#  (2020, 'Chairs'),
#  (2020, 'Fasteners'),
#  (2020, 'Furnishings'),
#  (2020, 'Labels'),
#  (2020, 'Paper'),
#  (2020, 'Phones'),
#  (2020, 'Storage'),
#  (2021, 'Accessories'),
#  (2021, 'Binders'),
#  (2021, 'Chairs'),
#  (2021, 'Furnishings'),
#  (2021, 'Labels'),
#  (2021, 'Paper'),
#  (2021, 'Phones'),
#  (2021, 'Storage')]

# %%
h=sorted(df['Order Date'].dt.year.unique())
sh = sorted(df['Sub-Category'].unique())

# %%
import multiprocessing as mp

# %%
def trying(x):
    print(x)
#     if h and sh in x :
#         print(i,j)
#     else:
#         print(f'{x} is listkeys')
#         print(f"{s} and {h} are not present in listkeys")
# # 
list(map(trying,x,h,sh))

# with mp.Pool() as pool:
#     pool.map(trying, x)

# %%
x_dict = dict(sales_by_year)
x_y = dict(x_dict['Sales'])
# x =list(x_y.keys())
print(x_y)
# Out:
# {(2018, 'Appliances'): 114.9, (2018, 'Art'): 1143.764, (2018, 'Binders'): 41.224000000000004, (2018, 'Furnishings'): 68.16, (2018, 'Phones'): 2200.024, (2018, 'Storage'): 954.73, (2018, 'Tables'): 1706.1840000000002, (2019, 'Accessories'): 13.98, (2019, 'Appliances'): 68.80999999999999, (2019, 'Art'): 102.06400000000001, (2019, 'Binders'): 116.024, (2019, 'Bookcases'): 3615.8292, (2019, 'Chairs'): 1347.0990000000002, (2019, 'Envelopes'): 317.576, (2019, 'Furnishings'): 360.5, (2019, 'Labels'): 75.17999999999999, (2019, 'Paper'): 159.69, (2019, 'Phones'): 371.168, (2019, 'Storage'): 95.152, (2019, 'Tables'): 2002.2075, (2020, 'Accessories'): 211.54999999999998, (2020, 'Appliances'): 346.38, (2020, 'Art'): 41.24, (2020, 'Binders'): 506.9200000000001, (2020, 'Bookcases'): 261.96, (2020, 'Chairs'): 1051.35, (2020, 'Fasteners'): 15.260000000000002, (2020, 'Furnishings'): 190.92, (2020, 'Labels'): 14.62, (2020, 'Paper'): 193.94400000000002, (2020, 'Phones'): 2222.878, (2020, 'Storage'): 444.808, (2021, 'Accessories'): 19.99, (2021, 'Binders'): 58.242, (2021, 'Chairs'): 373.332, (2021, 'Furnishings'): 106.238, (2021, 'Labels'): 6.16, (2021, 'Paper'): 64.07400000000001, (2021, 'Phones'): 147.168, (2021, 'Storage'): 353.23199999999997}

# %%
n_list = print(list(x_y.keys()))
# Out:
# [(2018, 'Appliances'), (2018, 'Art'), (2018, 'Binders'), (2018, 'Furnishings'), (2018, 'Phones'), (2018, 'Storage'), (2018, 'Tables'), (2019, 'Accessories'), (2019, 'Appliances'), (2019, 'Art'), (2019, 'Binders'), (2019, 'Bookcases'), (2019, 'Chairs'), (2019, 'Envelopes'), (2019, 'Furnishings'), (2019, 'Labels'), (2019, 'Paper'), (2019, 'Phones'), (2019, 'Storage'), (2019, 'Tables'), (2020, 'Accessories'), (2020, 'Appliances'), (2020, 'Art'), (2020, 'Binders'), (2020, 'Bookcases'), (2020, 'Chairs'), (2020, 'Fasteners'), (2020, 'Furnishings'), (2020, 'Labels'), (2020, 'Paper'), (2020, 'Phones'), (2020, 'Storage'), (2021, 'Accessories'), (2021, 'Binders'), (2021, 'Chairs'), (2021, 'Furnishings'), (2021, 'Labels'), (2021, 'Paper'), (2021, 'Phones'), (2021, 'Storage')]

# %%
# for i in n_list
ne_dict = dict(n_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 ne_dict = dict(n_list)
#
# TypeError: 'NoneType' object is not iterable

# %%
def pl(**lis):
    print(f"{key} is ")


print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 print(**sales_by_year)
#
# TypeError: 'Sales' is an invalid keyword argument for print()

# %%
df1=pd.crosstab(df['Category'],df['Region'])

# %%
df1
# Out:
# Region           Central  East  South  West
# Category
# Furniture              9     5      6     4
# Office Supplies       21    12      8    19
# Technology             5     4      0     7

# %%
df = df

# %%
df.shape
# Out:
# (100, 21)

# %%
# df1.to_csv('C:/Users/acesi/OneDrive/Desktop/Excel_files/sales.csv',header=True, index=False,)

# %%
data = pd.read_csv('C:/Users/acesi/OneDrive/Desktop/Excel_files/sales.csv')

# %%
data.head()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ### sorting

# %%
y_axis = sorted(df['Sales'])

# %%
# print(y_axis)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### testing Cases for some more improvement

# %%
plt.plot(df['Region'],df['Sales'])

# %%
x=df['Region']

# %%
plt.plot(x)

# %%
plt.plot(df['Sales'])

# %%
plt.plot()

# %%
data = list(df['Sales'])
data
# Out:
# [261.96,
#  731.9399999999999,
#  14.62,
#  957.5775,
#  22.368,
#  48.86,
#  7.28,
#  907.152,
#  18.504,
#  114.9,
#  1706.1840000000002,
#  911.424,
#  15.552000000000003,
#  407.97600000000006,
#  68.80999999999999,
#  2.544,
#  665.88,
#  55.5,
#  8.56,
#  213.48,
#  22.72,
#  19.46,
#  60.34,
#  71.37199999999999,
#  1044.63,
#  11.648,
#  90.57,
#  3083.4300000000003,
#  9.618000000000002,
#  124.20000000000002,
#  3.264,
#  86.304,
#  6.858000000000001,
#  15.76,
#  29.472,
#  1097.5440000000003,
#  190.92,
#  113.328,
#  532.3992,
#  212.058,
#  371.168,
#  147.168,
#  77.88,
#  95.616,
#  45.98,
#  17.46,
#  211.96,
#  45.0,
#  21.8,
#  38.22,
#  75.17999999999999,
#  6.16,
#  89.99,
#  15.260000000000002,
#  1029.95,
#  208.56,
#  32.400000000000006,
#  319.41,
#  14.56,
#  30.0,
#  48.48,
#  1.68,
#  13.98,
#  25.824,
#  146.73,
#  79.76,
#  213.115,
#  1113.024,
#  167.96800000000002,
#  75.88,
#  4.616,
#  19.05,
#  831.9360000000001,
#  97.04,
#  72.784,
#  1.2479999999999998,
#  9.708,
#  27.24,
#  19.3,
#  208.16,
#  16.740000000000002,
#  14.9,
#  21.39,
#  200.98400000000004,
#  230.376,
#  301.96,
#  19.99,
#  6.16,
#  158.36800000000002,
#  20.1,
#  73.584,
#  6.48,
#  12.96,
#  53.34,
#  32.96,
#  5.682000000000001,
#  96.53,
#  51.312,
#  77.88,
#  64.624]

# %%
import numpy as np
data = np.random.random((10, 3))

# %%
data
# Out:
# array([[0.71623747, 0.98343356, 0.52539763],
#        [0.72294158, 0.64715877, 0.73658327],
#        [0.35592691, 0.57828916, 0.03150681],
#        [0.09127418, 0.49448154, 0.95828202],
#        [0.58013405, 0.49347727, 0.67461745],
#        [0.76314824, 0.63728348, 0.74608145],
#        [0.74621179, 0.42420668, 0.11995285],
#        [0.30778364, 0.45329434, 0.00355871],
#        [0.14989339, 0.57353347, 0.93773814],
#        [0.97227885, 0.36827405, 0.40675618]])

# %%
col= tuple(df['Category'].unique())

# %%
col
# Out:
# ('Furniture', 'Office Supplies', 'Technology')

# %%
fig, axs = plt.subplots(1, 1)

# %%
data = np.random.random((10, 3))
columns = ("Column I", "Column II", "Column III")
axs.axis('tight')
axs.axis('off')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
axs.table(cellText=data,colLabels=col,loc='center')
# plt.show()

# %%
len(df)
# Out:
# 100

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Country/Region     object
# City               object
# State              object
# Postal Code       float64
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %%
df.shape
# Out:
# (100, 21)

# %%
df.iloc[0]
# Out:
# Row ID                                            1
# Order ID                             CA-2020-152156
# Order Date                               2020-11-08
# Ship Date                                2020-11-11
# Ship Mode                              Second Class
# Customer ID                                CG-12520
# Customer Name                           Claire Gute
# Segment                                    Consumer
# Country/Region                        United States
# City                                      Henderson
# State                                      Kentucky
# Postal Code                                 42420.0
# Region                                        South
# Product ID                          FUR-BO-10001798
# Category                                  Furniture
# Sub-Category                              Bookcases
# Product Name      Bush Somerset Collection Bookcase
# Sales                                        261.96
# Quantity                                          2
# Discount                                        0.0
# Profit                                      41.9136
# Name: 0, dtype: object

# %%
dict(df.iloc[0])
# Out:
# {'Row ID': 1,
#  'Order ID': 'CA-2020-152156',
#  'Order Date': '2020-11-08',
#  'Ship Date': '2020-11-11',
#  'Ship Mode': 'Second Class',
#  'Customer ID': 'CG-12520',
#  'Customer Name': 'Claire Gute',
#  'Segment': 'Consumer',
#  'Country/Region': 'United States',
#  'City': 'Henderson',
#  'State': 'Kentucky',
#  'Postal Code': 42420.0,
#  'Region': 'South',
#  'Product ID': 'FUR-BO-10001798',
#  'Category': 'Furniture',
#  'Sub-Category': 'Bookcases',
#  'Product Name': 'Bush Somerset Collection Bookcase',
#  'Sales': 261.96,
#  'Quantity': 2,
#  'Discount': 0.0,
#  'Profit': 41.9136}

# %%
list(df.iloc[0])
# Out:
# [1,
#  'CA-2020-152156',
#  '2020-11-08',
#  '2020-11-11',
#  'Second Class',
#  'CG-12520',
#  'Claire Gute',
#  'Consumer',
#  'United States',
#  'Henderson',
#  'Kentucky',
#  42420.0,
#  'South',
#  'FUR-BO-10001798',
#  'Furniture',
#  'Bookcases',
#  'Bush Somerset Collection Bookcase',
#  261.96,
#  2,
#  0.0,
#  41.9136]

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure()

# table
plt.subplot(121)

cell_text = []
for row in range(10):
    cell_text.append(df.iloc[row])

# plt.table(cellText=cell_text, colLabels=df.columns, loc='center')
# plt.axis('off')

# plot
# plt.subplot(222)
# plt.plot(table['x1'],table['x2'])

# # plot
# plt.subplot(224)
# plt.plot(table['x1'],table['x2'])

# plt.show()

# %% [markdown]
# #### Test Cases ends here

# %%
plt.figure(figsize=(15,8))
plt.bar(df['Sub-Category'],df['Sales'])
plt.show()

# %%
df = df.sort_values('Sales',ascending=True)

# %%
df_sorted_profit = df.sort_values('Sales',ascending=False)

# %%
del df_sorted

# %%
df_sorted['Sales'].head()
# Out:
# 75    1.248
# 61    1.680
# 15    2.544
# 30    3.264
# 70    4.616
# Name: Sales, dtype: float64

# %%
df_sorted['Sales'].max()

# %%
df_sorted.tail()
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 24      25  CA-2019-106320  2019-09-25  2019-09-30  Standard Class
# 35      36  CA-2020-117590  2020-12-08  2020-12-10     First Class
# 67      68  CA-2018-106376  2018-12-05  2018-12-10  Standard Class
# 10      11  CA-2018-115812  2018-06-09  2018-06-14  Standard Class
# 27      28  US-2019-150630  2019-09-17  2019-09-21  Standard Class
#
#    Customer ID    Customer Name    Segment Country/Region          City  ...  \
# 24    EB-13870      Emily Burns   Consumer  United States          Orem  ...
# 35    GH-14485        Gene Hale  Corporate  United States    Richardson  ...
# 67    BS-11590    Brendan Sweed  Corporate  United States       Gilbert  ...
# 10    BH-11710  Brosina Hoffman   Consumer  United States   Los Angeles  ...
# 27    TB-21520  Tracy Blumstein   Consumer  United States  Philadelphia  ...
#
#    Postal Code   Region       Product ID         Category Sub-Category  \
# 24     84057.0     West  FUR-TA-10000577        Furniture       Tables
# 35     75080.0  Central  TEC-PH-10004977       Technology       Phones
# 67     85234.0     West  OFF-AR-10002671  Office Supplies          Art
# 10     90032.0     West  FUR-TA-10001539        Furniture       Tables
# 27     19140.0     East  FUR-BO-10004834        Furniture    Bookcases
#
#                                          Product Name     Sales  Quantity  \
# 24      Bretford CR4500 Series Slim Rectangular Table  1044.630         3
# 35                                        GE 30524EE4  1097.544         7
# 67  Hunt BOSTON Model 1606 High-Volume Electric Pe...  1113.024         8
# 10           Chromcraft Rectangular Conference Tables  1706.184         9
# 27  Riverside Palais Royal Lawyers Bookcase, Royal...  3083.430         7
#
#     Discount     Profit
# 24       0.0   240.2649
# 35       0.2   123.4737
# 67       0.2   111.3024
# 10       0.2    85.3092
# 27       0.5 -1665.0522
#
# [5 rows x 21 columns]

# %%
orientation='vertical'

# %%
plt.bar(df_sorted_profit['Sub-Category'],df_sorted_profit['Sales'])
plt.show()

# %%
x= 'Sub-Category'
y='Sales'

x_sorted = list(df[x])
y_sorted = df.groupby(by=['Sub-Category']).aggregate({y: sum})

# %%
# x_sorted

# %%
y_sorted
# Out:
#                              Sales
# Sub-Category Order Date
# Accessories  2019-11-24    13.9800
#              2020-01-16    90.5700
#              2020-03-11    45.9800
#              2020-06-17    30.0000
#              2020-06-20    45.0000
# ...                            ...
# Storage      2021-11-13   230.3760
#              2021-12-09    27.2400
# Tables       2018-06-09  1706.1840
#              2019-09-25  1044.6300
#              2019-10-11   957.5775
#
# [96 rows x 1 columns]

# %%
y_x = y_sorted.sort_values('Sales',ascending=True)

# %%
y_x
# Out:
#                   Sales
# Sub-Category
# Fasteners       15.2600
# Labels          95.9600
# Accessories    245.5200
# Envelopes      317.5760
# Paper          417.7080
# Appliances     530.0900
# Binders        722.4100
# Furnishings    725.8180
# Art           1287.0680
# Storage       1847.9220
# Chairs        2771.7810
# Tables        3708.3915
# Bookcases     3877.7892
# Phones        4941.2380

# %%
list(y_x['Sales'])
# Out:
# [15.260000000000002,
#  95.96,
#  245.51999999999998,
#  317.576,
#  417.70799999999997,
#  530.09,
#  722.4100000000001,
#  725.818,
#  1287.068,
#  1847.922,
#  2771.781,
#  3708.3915,
#  3877.7892,
#  4941.238]

# %%
x_dict =dict(y_x)

# %%
x_dict
# Out:
# {'Sales': Sub-Category
#  Fasteners        15.2600
#  Labels           95.9600
#  Accessories     245.5200
#  Envelopes       317.5760
#  Paper           417.7080
#  Appliances      530.0900
#  Binders         722.4100
#  Furnishings     725.8180
#  Art            1287.0680
#  Storage        1847.9220
#  Chairs         2771.7810
#  Tables         3708.3915
#  Bookcases      3877.7892
#  Phones         4941.2380
#  Name: Sales, dtype: float64}

# %%
l=dict(x_dict["Sales"])

# %%
l
# Out:
# {'Fasteners': 15.260000000000002,
#  'Labels': 95.96,
#  'Accessories': 245.51999999999998,
#  'Envelopes': 317.576,
#  'Paper': 417.70799999999997,
#  'Appliances': 530.09,
#  'Binders': 722.4100000000001,
#  'Furnishings': 725.818,
#  'Art': 1287.068,
#  'Storage': 1847.922,
#  'Chairs': 2771.781,
#  'Tables': 3708.3915,
#  'Bookcases': 3877.7892,
#  'Phones': 4941.238}

# %%
_x = list(l.keys())

# %%
_x
# Out:
# ['Fasteners',
#  'Labels',
#  'Accessories',
#  'Envelopes',
#  'Paper',
#  'Appliances',
#  'Binders',
#  'Furnishings',
#  'Art',
#  'Storage',
#  'Chairs',
#  'Tables',
#  'Bookcases',
#  'Phones']

# %%
plt.bar(df_sorted['Sub-Category'],df_sorted['Sales'])
plt.show()

# %%
plt.bar(df_sorted_profit['Category'],df_sorted_profit['Sales'])
plt.show()

# %%
plt.barh(df_sorted['Category'],df_sorted['Sales'])
plt.show()

# %%
plt.bar(df_sorted_profit['Region'],df_sorted_profit['Sales'])
plt.show()

# %%
plt.bar(df_sorted_profit['State'],df_sorted_profit['Sales'])
plt.show()

# %%
plt.bar(df_sorted_profit['City'],df_sorted_profit['Sales'])
plt.show()

# %%
plt.bar(df_sorted['Category'],df_sorted['Profit'])
plt.show()

# %% [markdown]
# ### filtering

# %%
this_index = list(df[df['Region']=='South'].index)
data = df.drop(df.index[this_index],axis=0)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Region'],df['Sales'])
plt.show()

# %%
plt.bar(data['Region'],data['Sales'])
plt.show()

# %%
df['Region'].value_counts()

# %%
data['Region'].value_counts()

# %%
df.groupby('Region').sum()

# %%
data.groupby('Region').sum()

# %%
sales = pd.read_csv("C:/Users/acesi/OneDrive/Desktop/Excel_files/sales.csv")

# %%
sales.groupby('Region').sum()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
dfp = df.pivot(index='Sales', columns='Sub-Category', values='Profit')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\acesi\OneDrive\Desktop\Aces\my_practice\interpretered\Untitled1.ipynb Cell 129 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/acesi/OneDrive/Desktop/Aces/my_practice/interpretered/Untitled1.ipynb#Y215sZmlsZQ%3D%3D?line=0'>1</a> dfp = df.pivot(index='Sales', columns='Sub-Category', values='Profit')
#
# File c:\Users\acesi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:7882, in DataFrame.pivot(self, index, columns, values)
#    7877 @Substitution("")
#    7878 @Appender(_shared_docs["pivot"])
#    7879 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7880     from pandas.core.reshape.pivot import pivot
# -> 7882     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Users\acesi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\pivot.py:520, in pivot(data, index, columns, values)
#     518     else:
#     519         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520 return indexed.unstack(columns_listlike)
#
# File c:\Users\acesi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4157, in Series.unstack(self, level, fill_value)
#    4114 """
#    4115 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4116
#    (...)
#    4153 b    2    4
#    4154 """
#    4155 from pandas.core.reshape.reshape import unstack
# -> 4157 return unstack(self, level, fill_value)
#
# File c:\Users\acesi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\reshape.py:491, in unstack(obj, level, fill_value)
#     489 if is_1d_only_ea_dtype(obj.dtype):
#     490     return _unstack_extension_series(obj, level, fill_value)
# --> 491 unstacker = _Unstacker(
#     492     obj.index, level=level, constructor=obj._constructor_expanddim
#     493 )
#     494 return unstacker.get_result(
#     495     obj._values, value_columns=None, fill_value=fill_value
#     496 )
#
# File c:\Users\acesi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\reshape.py:140, in _Unstacker.__init__(self, index, level, constructor)
#     133 if num_cells > np.iinfo(np.int32).max:
#     134     warnings.warn(
#     135         f"The following operation may generate {num_cells} cells "
#     136         f"in the resulting pandas object.",
#     137         PerformanceWarning,
#     138     )
# --> 140 self._make_selectors()
#
# File c:\Users\acesi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\reshape.py:192, in _Unstacker._make_selectors(self)
#     189 mask.put(selector, True)
#     191 if mask.sum() < len(self.index):
# --> 192     raise ValueError("Index contains duplicate entries, cannot reshape")
#     194 self.group_index = comp_index
#     195 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
ax = dfp.plot(kind='bar', title='Bar Chart of Colors', figsize=(6, 4))
ax.set(ylabel='Sales')
ax.legend(title='Sub-Category', bbox_to_anchor=(1, 1), loc='upper left')
ax.grid(axis='x')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\acesi\OneDrive\Desktop\Aces\my_practice\interpretered\Untitled1.ipynb Cell 130 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/acesi/OneDrive/Desktop/Aces/my_practice/interpretered/Untitled1.ipynb#Y216sZmlsZQ%3D%3D?line=0'>1</a> ax = dfp.plot(kind='bar', title='Bar Chart of Colors', figsize=(6, 4))
#       <a href='vscode-notebook-cell:/c%3A/Users/acesi/OneDrive/Desktop/Aces/my_practice/interpretered/Untitled1.ipynb#Y216sZmlsZQ%3D%3D?line=1'>2</a> ax.set(ylabel='Sales')
#       <a href='vscode-notebook-cell:/c%3A/Users/acesi/OneDrive/Desktop/Aces/my_practice/interpretered/Untitled1.ipynb#Y216sZmlsZQ%3D%3D?line=2'>3</a> ax.legend(title='Sub-Category', bbox_to_anchor=(1, 1), loc='upper left')
#
# NameError: name 'dfp' is not defined

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# from re import T


ax = sns.barplot(data=df, x='Category', y='Sales', hue='Region')
ax.set(xlabel='Category', title='Bar Chart of Colors')
ax.legend(title='Region', bbox_to_anchor=(1, 1), loc='upper left')
plt.xticks(rotation=90)
ax.grid(axis='x')

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
from  matplotlib.widgets import LassoSelector
x=df['Category']
y=df['Sales']

ax = plt.subplot()
ax.plot(x, y)

def onselect(verts):
    print(verts)
lasso = LassoSelector(ax, onselect)
# Out:
# C:\Users\acesi\AppData\Local\Temp\ipykernel_13640\206103089.py:10: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   lasso = LassoSelector(ax, onselect)

# %%
import matplotlib.pyplot  as plt

# %%
from  matplotlib.widgets import LassoSelector

# %%
sns.set_style("whitegrid")
# plt.figure(figsize=(7,5))

fig, plot1 = plt.subplots(figsize =(7, 5))


  
sns.boxplot( y = 'Quantity', data = df,  ) #x = 'Region',
# plt.scatter(x='Region',y=df['Quantity'], data=df)
plt.show()

# %%
fig

# %%
fig, plot1 = plt.subplots(figsize =(7, 5))


sns.boxplot( y = 'Quantity',x = 'Region', data = df,  ) #x = 'Region',
plt.show()

# %%
fig

# %%
len(df['Sub-Category'].unique())
# Out:
# 17

# %%
df.boxplot( column =['Profit'], grid = False)
# Out:
# <AxesSubplot:>

# %%
import random
colors_ = lambda n: list(map(lambda i: "#" + "%06x" % random.randint(0, 0xFFFFFF),range(n)))

# %%
l = list(map(colors_, [10]))

# %%
l[0]
# Out:
# ['#748e7d',
#  '#2f2b91',
#  '#9289ec',
#  '#8a68fe',
#  '#4b7194',
#  '#661a21',
#  '#3bdafd',
#  '#49c330',
#  '#b0a8a8',
#  '#37e2ac']
